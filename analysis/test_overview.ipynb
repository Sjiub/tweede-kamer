# %% [markdown]
# # Overview results

# %%
import pandas as pd

df = pd.read_csv("~/ownCloud/Personal/Structures/Democracy_Slaps/tweede-kamer/data/results/report_tk_debate_nl_nl_Mungert_gemma-3-27b-it-GGUF_2025-05-15 18:14:18.csv")

# %%
df.head()
# Out:
#                file_id            speaker_name speaker_party  \
# 0   h-tk-20212022-81-6         De heer Grinwis            CU
# 1   h-tk-20162017-7-23         De heer Servaes          PvdA
# 2   h-tk-20192020-45-7          De heer Hijink            SP
# 3  h-tk-20172018-102-6  Mevrouw Aukje de Vries           VVD
# 4  h-tk-20222023-37-34         De heer Grinwis            CU
#
#                                          speech_text       jaar        date  \
# 0  Ik heb echt alle waardering voor de indieners ...  2021-2022   18-5-2022
# 1  Ook steun daarvoor, maar inderdaad volgens de ...  2016-2017   4-10-2016
# 2  Dat is niet zo verschrikkelijk veel. Ik heb he...  2019-2020   23-1-2020
# 3       Ik ben nog niet aan het eind van mijn tekst.  2017-2018    4-7-2018
# 4  Voorzitter, dank u wel. Op 26 september klonk ...  2022-2023  20-12-2022
#
#   kamer     category                                              title  \
# 0    tk  handelingen  6 Het volledig democratiseren van de waterscha...
# 1    tk  handelingen                      23 Regeling van werkzaamheden
# 2    tk  handelingen  7 VAO Financiële problemen bij diverse Jeugdzo...
# 3    tk  handelingen                               6 Voorjaarsnota 2018
# 4    tk  handelingen                  34 Gasmarkt en leveringszekerheid
#
#                                                  url  ...   vergadernummer  \
# 0  https://zoek.officielebekendmakingen.nl/h-tk-2...  ...   nr. 81, item 6
# 1  https://zoek.officielebekendmakingen.nl/h-tk-2...  ...   nr. 7, item 23
# 2  https://zoek.officielebekendmakingen.nl/h-tk-2...  ...   nr. 45, item 7
# 3  https://zoek.officielebekendmakingen.nl/h-tk-2...  ...  nr. 102, item 6
# 4  https://zoek.officielebekendmakingen.nl/h-tk-2...  ...  nr. 37, item 34
#
#   standardized_name                                     speech_text_en  \
# 0           grinwis  I really appreciate the submitters and underst...
# 1           servaes  Also support for that, but indeed according to...
# 2            hijink  That's not terribly much. I have amended the o...
# 3    de aukje vries                    I haven't finished my text yet.
# 4           grinwis  Chairman, thank you. There was no loud bang on...
#
#   final_label  duration      energy  \
# 0           0       NaN         NaN
# 1           0       NaN         NaN
# 2           0       NaN         NaN
# 3           0       NaN         NaN
# 4           0  9.809477  705.437611
#
#                                                  raw is_timeout  \
# 0                                                NaN        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3                                                NaN        NaN
# 4  {'id': 'chatcmpl-53141d7f-8a69-48b6-a735-759ea...      False
#
#                                        power-samples  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [72.38, 72.53, 72.03, 71.79, 71.96, 71.74, 71....
#
#                                               result
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'id': 'chatcmpl-53141d7f-8a69-48b6-a735-759ea...
#
# [5 rows x 21 columns]

# %%
new_df = df

print("df raw: ", len(new_df))
print("df dropna: ", len(new_df.dropna()))
# Out:
# df raw:  200
# df dropna:  100

# %% [markdown]
# ## Log data
# Test execution start: May 15  17:57:50.977
#
# First 50 batch: May 15  18:13:13.645:
#
# * 📊 Forecast Report
# * ✅ Finished: 50/200 (25.00%)
# * ⏱️ Running since: 2025-05-15 17:57:54  Avg Duration: 17.95s
# * ⏳ Estimated Remaining Time: 44.87 min
# * ⚡ Estimated Total Energy: 257976.90 J
# * 🤑 Estimated Cost: $0.20 💰
#
# Second 50 batch: May 15  18:14:17.179
#
# * 📊 Forecast Report
# * ✅ Finished: 100/200 (50.00%)
# * ⏱️ Running since: 2025-05-15 17:57:54  Avg Duration: 18.59s
# * ⏳ Estimated Remaining Time: 30.98 min
# * ⚡ Estimated Total Energy: 267195.00 J
# * 🤑 Estimated Cost: $0.41 💰
#
#
# interpretation:
# The test was supposed to run for 200 elements but terminated after 100 elements.
# Batch size was 50 and multiproccessing was 2. Suspected error: execution didn't run in a loop, therefore the runners just terminated after execution.
#
# Usefulness of forcast.Time forcast:
# 1) The first test computed 1/4 of the computation needed ~15min for it and forcasted 45 min for it. that seems to be reasonable.
# 2) The second computed 1/2 of the computation while needing about a second longer and forcasted 30 min for the completion.
# 3) The calculation seems to be correct, but 30 min is a bit long, possible the distribution of computation duration might have some outliers in the second sample
#
# Open question how did estimated cost change from 0.20 to 0.40 and how accurate are cost prediction?
#
# -> Eyeballing cost, the costs are in a plausible range. Its insanly energy efficiant.
#
# Comparison chatgpt 4o prices:
# * Input tokens: $2.50 per 1 million tokens
# * Output tokens: $10.00 per 1 million tokens

# %% [markdown]
# ## Results:

# %%
new_df = df.dropna()

# %%
new_df["result"][4]
# Out:
# '{\'id\': \'chatcmpl-53141d7f-8a69-48b6-a735-759ead630af3\', \'object\': \'chat.completion\', \'created\': 1747325379, \'model\': \'/opt/ai/models/models--Mungert--gemma-3-27b-it-GGUF/blobs/f3b2259712093260f0f5336d879c8270f23429d1693f6ae5b756086d2c695668\', \'choices\': [{\'index\': 0, \'message\': {\'role\': \'assistant\', \'content\': \'```json\\n{\\n  "mentions": [],\\n  "found_fallacy": [],\\n  "summary": {\\n    "count": 0,\\n    "average_confidence": 0.0,\\n    "highest_confidence": 0.0,\\n    "lowest_confidence": 0.0\\n  },\\n  "speech_relation": {\\n    "type": "independent",\\n    "justification": "The provided text is a statement indicating the speaker is not finished, and does not relate to any prior statement.",\\n    "confidence": 1.0\\n  }\\n}\\n```\'}, \'logprobs\': None, \'finish_reason\': \'stop\'}], \'usage\': {\'prompt_tokens\': 1905, \'completion_tokens\': 133, \'total_tokens\': 2038}}'

# %%
def clean_result(text: str):
        """
            Multiple ways to resolve different ways a llm might return json.
            1. normal
            2. embedded in text but marked as specified in the template
            3. normal json but with '' instead of ""
        """
        import json
        import ast
        import re
        text = str(text).strip()
        # Try to extract JSON block from markdown-style ```json ... ``` block
        if re.search(r'```json\b', text, re.IGNORECASE):
            try:
                match = re.search(r'```json\s*(.*?)\s*```', text, re.DOTALL | re.IGNORECASE)
                if match:
                    json_str = match.group(1).strip()
                    return json.loads(json_str)
            except Exception:
                pass

        # Try raw JSON
        try:
            return json.loads(text)
        except Exception:
            pass

        # Try using ast.literal_eval for single-quoted "JSON"
        try:
            return ast.literal_eval(text)
        except Exception:
            pass

        raise ValueError("Unable to parse JSON from text.")

# %%
new_df["compute"]= new_df["raw"].apply(clean_result)
# Out:
# /tmp/ipykernel_6305/455564670.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["compute"]= new_df["raw"].apply(clean_result)

# %% [markdown]
# Failes to extract json as it returns a string instead of expected json

# %%
new_df["compute"][4]["choices"][0]["message"]['content']
# Out:
# '```json\n{\n  "mentions": [],\n  "found_fallacy": [],\n  "summary": {\n    "count": 0,\n    "average_confidence": 0.0,\n    "highest_confidence": 0.0,\n    "lowest_confidence": 0.0\n  },\n  "speech_relation": {\n    "type": "independent",\n    "justification": "The provided text is a statement indicating the speaker is not finished, and does not relate to any prior statement.",\n    "confidence": 1.0\n  }\n}\n```'

# %%
def new_cleaner(data):
    data = data["choices"][0]["message"]['content']
    return clean_result(data)

# %%
new_df["results"]= new_df["compute"].apply(new_cleaner)
# Out:
# /tmp/ipykernel_6305/1964376841.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["results"]= new_df["compute"].apply(new_cleaner)

# %%
new_df["results"][4]
# Out:
# {'mentions': [],
#  'found_fallacy': [],
#  'summary': {'count': 0,
#   'average_confidence': 0.0,
#   'highest_confidence': 0.0,
#   'lowest_confidence': 0.0},
#  'speech_relation': {'type': 'independent',
#   'justification': 'The provided text is a statement indicating the speaker is not finished, and does not relate to any prior statement.',
#   'confidence': 1.0}}

# %%
def compute_fallacy(data):
    return data["summary"]["count"] > 0

new_df["predicted"] = new_df["results"].apply(compute_fallacy)
# Out:
# /tmp/ipykernel_6305/819846700.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["predicted"] = new_df["results"].apply(compute_fallacy)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt

y_true = new_df["final_label"]
y_pred = new_df["predicted"]

# Use boolean labels for computation
labels = [False, True]
label_names = ["No Ad Hominem", "Ad Hominem"]

# Compute accuracy
accuracy = accuracy_score(y_true, y_pred)
precision_score = precision_score(new_df["final_label"], new_df["predicted"], zero_division=0)
recall_score= recall_score(new_df["final_label"], new_df["predicted"], zero_division=0)
f1_score = f1_score(new_df["final_label"], new_df["predicted"], zero_division=0)


print(f"Precision: {precision_score}")
print(f"Recall: {recall_score}")
print(f"F1 Score: {f1_score}")
print(f"✅ Accuracy: {accuracy:.2%}")

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=labels)

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=label_names,
            yticklabels=label_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()
# Out:
# Precision: 0.125
# Recall: 0.14285714285714285
# F1 Score: 0.13333333333333333
# ✅ Accuracy: 87.00%
